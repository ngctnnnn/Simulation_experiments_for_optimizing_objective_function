# %% [markdown]
# ## Constants and import

# %%
import numpy as np
import pandas as pd
from IPython import display
from time import sleep
import math
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %% [markdown]
# ## Test function
# Denote $d = len(individual)$

# %% [markdown]
# ### Sphere function
#
# <div align='center'>
# $f(x) = \sum_{i = 1}^d{x_i^2}$
# </div>
#
# - where $x_i \in \left[-5.12;5.12\right]$
# - Global minimum: $f(x^*) = 0$, at $x^* = (0,...,0)$

# %%
def Sphere(d):
    sum = 0
    for i in d:
        sum += i*i
    return sum

# %%
dimension = 2
popsize= 32#@param
bound_lower = -10#@param
bound_upper = 10#@param

x = np.linspace(bound_lower, bound_upper, 100)
y = np.linspace(bound_lower, bound_upper, 100)
X, Y = np.meshgrid(x, y)

Z = Sphere([X, Y])
plt.figure(figsize=(12, 12))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
# plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
# plt.axis('square')
# plt.plot()

# %% [markdown]
# ### Rastrigin function
#
# <div align='center'>
# $f(x) = 10d + \sum_{i=1}^d{\left[x_i^2 - 10\cos\left(2\pi x_i\right)\right]}$
# </div>
#
# - where $x_i \in \left[-5.12;5.12\right]$
# - Global minimum: $f(x^*) = 0$, at $x^* = (0,...,0)$

# %%
def Rastrigin(d):
    sum = 10 * len(d)
    for i in d:
        sum += i**2 - 10 * np.cos(2*np.pi*i)
    return sum

# %%
dimension = 2
popsize= 32#@param
bound_lower = -10#@param
bound_upper = 10#@param

x = np.linspace(bound_lower, bound_upper, 100)
y = np.linspace(bound_lower, bound_upper, 100)
X, Y = np.meshgrid(x, y)

Z = Rastrigin([X, Y])
plt.figure(figsize=(12, 12))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
# plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
# plt.axis('square')
# plt.plot()

# %% [markdown]
# ### Rosenbrock function
#
# <div align='center'>
# $f(x) = \sum_{i = 1}^{d-1}\left[100\left(x_{i + 1} - x_i^2\right)^2 + \left(x_i - 1\right)^2\right]$
# </div>
#
# - where $x_i \in \left[-2.048; 2.048\right]$
#
# - Global minimum: $f(x^*) = 0$, at $x^* =(1,...1)$

# %%
def Rosenbrock(d):
    sum = 0
    for i in range(len(d) - 1):
        sum += 100 * (d[i + 1] - d[i]**2)**2 + (d[i] - 1)**2
    return sum

# %%
dimension = 2
popsize= 32#@param
bound_lower = -10#@param
bound_upper = 10#@param

x = np.linspace(bound_lower, bound_upper, 100)
y = np.linspace(bound_lower, bound_upper, 100)
X, Y = np.meshgrid(x, y)

Z = Rosenbrock([X, Y])
plt.figure(figsize=(12, 12))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
# plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
# plt.axis('square')
# plt.plot()

# %% [markdown]
# ### Griewank function
# <div align='center'>
# $f(x) = \sum_{i = 1}^d{\frac{x_i^2}{4000}} - \prod_{i = 1}^d{\cos\left(\frac{x_i}{\sqrt{i}}\right) + 1}$
# </div>
#
# - where $x_i \in \left[-600; 600\right]$
# - Global minimum: $f(x^*) = 0$, at $x^* = (0,...,0)$

# %%
def Griewank(d):
    sum_1 = 0
    for i in d:
        sum_1 += (i*i)/4000
    sum_2 = 1
    for i in range(len(d)):
        sum_2 *= np.cos(d[i]/math.sqrt(i + 1))
    return sum_1 - sum_2 + 1

# %%
dimension = 2
popsize= 32#@param
bound_lower = -10#@param
bound_upper = 10#@param

x = np.linspace(bound_lower, bound_upper, 100)
y = np.linspace(bound_lower, bound_upper, 100)
X, Y = np.meshgrid(x, y)

Z = Griewank([X, Y])
plt.figure(figsize=(12, 12))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
# plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
# plt.axis('square')
# plt.plot()

# %% [markdown]
# ### Ackley function
# <div align='center'>
# $f(x) = -a\exp\left(-b\sqrt{\frac{1}{d}\sum_{i=1}^d{x_i^2}}\right) - \exp\left(\frac{1}{d}\sum_{i=1}^d{\cos\left(cx_i\right)}\right) + a + \exp{(1)}$
# </div>
#
# - where $x_i \in \left[-32.768; 432.768\right]$
#
# - $a = 20$, $b =0.2$ and $c = 2\pi$ (recommended)
# - Global minimum: $f(x^*) = 0$, at $x^* = (0,...,0)$

# %%
def Ackley(d):
    a = 20
    b = 0.2
    c = 2 * np.pi
    sum1 = 0
    sum2 = 0
    for i in range(len(d)):
        sum1 += d[i] ** 2
        sum2 += np.cos(c * d[i])
    term1 = -a * np.exp(-b * np.sqrt(sum1 / len(d)))
    term2 = -np.exp(sum2 / len(d))

    return term1 + term2 + a + np.exp(1)

# %%
dimension = 2
popsize= 32#@param
bound_lower = -33#@param
bound_upper = 33#@param

x = np.linspace(bound_lower, bound_upper, 100)
y = np.linspace(bound_lower, bound_upper, 100)
X, Y = np.meshgrid(x, y)

Z = Ackley([X, Y])
plt.figure(figsize=(12, 12))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
# plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
# plt.axis('square')
# plt.plot()

# %% [markdown]
# # Differential Evolution (DE)

# %%
def DE(test_function, dimension, bounds, F_scale, cross_prob, popsize, max_evals):
    """
    Differential Evolution algorithm

    Args:
    test_function -- function to conduct
    bound_lower -- lower bound of the test function
    bound_upper -- upper bound of the test function
    F_scale -- scale factor on mutation
    cross_prob -- the probability of 2 individuals to do crossover
    popsize -- the population size
    max_evals -- the maximum fitness evaluation for the algorithm

    Returns:
    results -- best results after finishing the algorithm
    all_pops -- all the population 
    """

    eps = 0.00001

    bound_lower, bound_upper = np.asarray(bounds).T

    diff = np.fabs(bound_lower - bound_upper)

    pop = bound_lower + diff * np.random.rand(popsize, dimension)

    fitness = np.asarray([test_function(ind) for ind in pop])
    num_eval = 0
    
    best_idx = np.argmin(fitness)
    best = pop[best_idx]

    results = []
    all_pops = []
    results.append((np.copy(best), fitness[best_idx], num_eval))
    results.append((np.copy(best), fitness[best_idx], num_eval+len(pop)))
    all_pops.append(np.copy(pop))
    generation_count = 0

    while True:
        if num_eval > max_evals:
            break
        for i in range(popsize):
            # Mutation step
            idxes = [idx for idx in range(popsize) if idx != i]
            a, b, c = pop[np.random.choice(idxes, 3, replace=False)]
            mutant = np.clip(F_scale*(b - c) + a, bound_lower, bound_upper)

            # Create cross point
            cross_points = np.random.rand(dimension) < cross_prob
            if not np.any(cross_points):
                cross_points[np.random.randint(0, dimension)] = True
            
            # Offspring
            trial = np.where(cross_points, mutant, pop[i])

            # Evaluate fitness
            f = test_function(trial)
            num_eval += 1

            if f < fitness[i]:
                pop[i] = trial
                fitness[i] = f 
                if f < fitness[best_idx]:
                    best = trial
                    best_idx = i

        results.append((np.copy(best), fitness[best_idx], num_eval))
        all_pops.append(np.copy(pop))
        num_eval += 1
        if abs(test_function(best)) < eps:
            break

        generation_count += 1

    return results, all_pops, generation_count

# %% [markdown]
# ## Constant configuration

# %%
F_scale=0.8#@param
cross_prob=0.7#@param

# %% [markdown]
# ## Test algorithm

# %%
np.random.rand(seed_number)
test_function = Sphere
all_results = []

all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Griewank#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -5.12#@param
bound_upper = 5.12#@param
results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)

# %%
results
# Out:
# [(array([0.06301181, 0.24076005]), -3.9671312617707755, 1024),
#  (array([0.06301181, 0.24076005]), -3.9671312617707755, 2048),
#  (array([-0.01196395,  0.13087758]), -3.99129449417488, 3073),
#  (array([-0.01196395,  0.13087758]), -3.99129449417488, 4098),
#  (array([0.03119733, 0.12342691]), -3.991412338961232, 5123),
#  (array([0.02993986, 0.03044907]), -3.9986397645335496, 6148),
#  (array([0.02993986, 0.03044907]), -3.9986397645335496, 7173),
#  (array([0.02993986, 0.03044907]), -3.9986397645335496, 8198),
#  (array([0.02993986, 0.03044907]), -3.9986397645335496, 9223),
#  (array([0.02993986, 0.03044907]), -3.9986397645335496, 10248),
#  (array([0.02993986, 0.03044907]), -3.9986397645335496, 11273),
#  (array([ 0.00186258, -0.02148516]), -3.999765613038536, 12298),
#  (array([ 0.00186258, -0.02148516]), -3.999765613038536, 13323),
#  (array([0.01054389, 0.01397329]), -3.9997911278046936, 14348),
#  (array([0.01054389, 0.01397329]), -3.9997911278046936, 15373),
# ...

# %% [markdown]
# ## Experiment

# %% [markdown]
# ### Sphere

# %% [markdown]
# #### d = 2

# %% [markdown]
# ##### popsize = 32

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Sphere#@param
seed_number = 19520925#@param
popsize = 32#@param
bound_lower = -6
bound_upper = 6

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-0.00141157, -0.00091197]), 2.8242164617650832e-06, 955),
#  (array([-0.00044653, -0.0015762 ]), 2.6837950982044164e-06, 724),
#  (array([-0.00307854, -0.00071052]), 9.982261872033832e-06, 922),
#  (array([-0.00088893, -0.0007655 ]), 1.3761891539923374e-06, 856),
#  (array([-0.00030528, -0.00094958]), 9.948953931415361e-07, 856),
#  (array([ 0.00109184, -0.00280552]), 9.063036452762781e-06, 1054),
#  (array([-0.00028799, -0.00209702]), 4.4804172471101176e-06, 922),
#  (array([ 0.00149765, -0.00198422]), 6.180068010327613e-06, 955),
#  (array([-0.00028438,  0.00049232]), 3.232467782092233e-07, 922),
#  (array([-0.00160863, -0.00077168]), 3.1831881371650972e-06, 988)]

# %%
print(f"Mean fitness Sphere (d=2, n =32): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Sphere (d=2, n =32): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Sphere (d=2, n =32): 4.109131460471204e-06
# Stddev fitness Sphere (d=2, n =32): 3.154390447158125e-06

# %% [markdown]
# ##### popsize = 64

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Sphere#@param
seed_number = 19520925#@param
popsize = 64#@param
bound_lower = -6
bound_upper = 6

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([0.00049154, 0.00188654]), 3.8006265713257744e-06, 1688),
#  (array([ 0.00224547, -0.0001837 ]), 5.075902093492949e-06, 2078),
#  (array([-0.00043408, -0.00211635]), 4.667344763266595e-06, 1948),
#  (array([-8.50778286e-05, -5.77914769e-04]), 3.4122371706338185e-07, 1493),
#  (array([-0.00033804,  0.00239577]), 5.854007273259387e-06, 1948),
#  (array([0.000237  , 0.00191231]), 3.7130781276022985e-06, 1493),
#  (array([-0.00073946, -0.00038959]), 6.985844567440093e-07, 1948),
#  (array([ 0.0003346 , -0.00262355]), 6.994974292089464e-06, 1688),
#  (array([-0.00128099,  0.00196927]), 5.518949507876652e-06, 1623),
#  (array([ 0.00274893, -0.00010861]), 7.568402455209473e-06, 1753)]

# %%
print(f"Mean fitness Sphere (d=2, n = 64): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Sphere (d=2, n = 64): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Sphere (d
#           4.41901294e-04, -5.48700983e-04, -1.65518024e-03,  6.89128954e-04,
#           6.65982393e-04,  9.02889513e-05]), 8.926193314988763e-06, 178009),
#  (array([ 0.00103373,  0.00174572,  0.00140695, -0.00039855, -0.00013181,
#           0.00038863,  0.00031842, -0.00079459, -0.00015653, -0.00119191]),
#   8.600806708466675e-06,
#   170827),
#  (array([ 0.00016217, -0.00025963,  0.00058185, -0.00068953,  0.00171137,
# ...

# %%
print(f"Mean fitness Sphere (d=10, n = 512): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Sphere (d=10, n = 512): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Sphere (d=10, n = 512): 8.338840607677262e-06
# Stddev fitness Sphere (d=10, n = 512): 1.0120368239700667e-06

# %% [markdown]
# ##### popsize = 1024

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Sphere#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -6#@param
bound_upper = 6#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-1.40421726e-03,  9.06651125e-04, -1.92021421e-04,  1.42696068e-03,
#          -5.72182313e-05,  5.71405250e-04, -3.52362816e-04, -4.34381866e-04,
#           1.06521608e-03, -2.61946632e-04]), 6.7128577464114585e-06, 352598),
#  (array([ 0.00101786,  0.0015085 ,  0.00093924, -0.00068055,  0.00108876,
#           0.00098158, -0.00014032,  0.00028275, -0.00121009,  0.00108243]),
#   9.541433987487702e-06,
#   345423),
#  (array([-9.06989870e-04,  5.72239865e-04, -7.64969483e-04, -9.58936458e-05,
#           3.60176348e-04, -4.43607431e-04,  8.93944081e-04,  2.12190255e-03,
#          -1.37756660e-03, -6.38088614e-04]), 9.677430809153353e-06, 342348),
#  (array([ 0.00047145, -0.000131  ,  0.00085786,  0.00084607,  0.00012669,
#           0.00082   ,  0.00071694,  0.00091872,  0.00140814, -0.00141383]),
#   7.719470776458956e-06,
#   352598),
#  (array([ 7.56277149e-04,  2.31612719e-05, -2.15890112e-03,  7.32069351e-04,
# ...

# %%
print(f"Mean fitness Sphere (d=10, n = 1024): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Sphere (d=10, n = 1024): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Sphere (d=10, n = 1024): 8.698078750169516e-06
# Stddev fitness Sphere (d=10, n = 1024): 9.800794399192997e-07

# %% [markdown]
# ### Rastrigin

# %% [markdown]
# #### d = 2

# %% [markdown]
# ##### popsize = 32

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Rastrigin#@param
seed_number = 19520925#@param
popsize = 32#@param
bound_lower = -6#@param
bound_upper = 6#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([ 9.00551042e-05, -1.21415109e-04]), 4.533566649200793e-06, 1912),
#  (array([ 1.43869719e-04, -3.43768974e-05]), 4.340871580410521e-06, 2110),
#  (array([-4.31068463e-05,  2.09613072e-04]), 9.085531104346956e-06, 1780),
#  (array([ 1.19283671e-04, -9.49011435e-05]), 4.6096045256405205e-06, 1912),
#  (array([-1.35585688e-04, -7.78936871e-05]), 4.850865906291801e-06, 1846),
#  (array([-1.91794433e-04,  6.48841854e-05]), 8.13309507563531e-06, 1813),
#  (array([-1.89206128e-04, -6.93609475e-05]), 8.056681959800471e-06, 2209),
#  (array([ 1.94857237e-04, -4.98845250e-05]), 8.026508170999591e-06, 2110),
#  (array([ 1.09474404e-05, -1.34212498e-05]), 5.9512943906270266e-08, 2209),
#  (array([ 4.37192715e-05, -1.84421421e-04]), 7.126765879661434e-06, 1978)]

# %%
print(f"Mean fitness Rastrigin (d=2, n = 32): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Rastrigin (d=2, n = 32): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Rastrigin (d=2, n = 32): 5.8823003795893666e-06
# Stddev fitness Rastrigin (d=2, n = 32): 2.588137772196349e-06

# %% [markdown]
# ##### popsize = 64

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Rastrigin#@param
seed_number = 19520925#@param
popsize = 64#@param
bound_lower = -6#@param
bound_upper = 6#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([
d=10, n = 256): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Rastrigin (d=10, n = 256): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Rastrigin (d=10, n = 256): 8.47807971720016e-06
# Stddev fitness Rastrigin (d=10, n = 256): 1.2469902958781933e-06

# %% [markdown]
# ##### popsize = 512

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Rastrigin#@param
seed_number = 19520925#@param
popsize = 512#@param
bound_lower = -6#@param
bound_upper = 6#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([ 0.05107028, -0.00401008, -0.96505259, -0.9794326 ,  0.0856312 ,
#           0.00710481, -0.91547286, -0.94186023, -0.04138348, -0.01032127]),
#   8.282041509054007,
#   1000348),
#  (array([-9.96347606e-01,  1.00064174e+00, -1.18013744e-02, -2.83545907e-02,
#          -5.47513039e-02, -1.04286374e-01,  1.02614358e+00,  3.16626493e-04,
#          -3.57678164e-02,  1.03750620e+00]), 7.647403295240096, 1000348),
#  (array([-0.05720299,  0.02200149,  0.98995335, -1.01436253, -0.91611966,
#           0.96309407,  0.03181826,  0.03708977,  0.00974158, -0.00769337]),
#   6.701584362340528,
#   1000348),
#  (array([ 7.59036943e-02,  2.12724259e-02,  5.58740256e-02, -3.68863769e-04,
#           1.07676529e-02, -6.34812410e-02, -9.60778683e-03, -1.00129912e+00,
#           8.16345230e-02, -8.78196066e-02]), 6.44293876401426, 1000348),
#  (array([ 0.02143149, -0.8898443 , -0.02210846,  0.97562842, -0.01855694,
# ...

# %%
print(f"Mean fitness Rastrigin (d=10, n = 512): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Rastrigin (d=10, n = 512): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Rastrigin (d=10, n = 512): 7.411530034207104
# Stddev fitness Rastrigin (d=10, n = 512): 0.7724444438558713

# %% [markdown]
# ##### popsize = 1024

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Rastrigin#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -6#@param
bound_upper = 6#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-0.93468534,  0.99727284,  0.04856348, -0.04714893, -0.12553016,
#          -0.92447281, -0.00613068,  0.00576142, -1.02796623,  0.03694387]),
#   10.024364366821832,
#   1000398),
#  (array([-0.03626123, -1.05841922,  0.93445978, -0.01011727,  1.03649394,
#           0.06910275,  0.02022381,  1.07464248,  0.0728098 , -0.97967383]),
#   10.434786891308278,
#   1000398),
#  (array([-0.85161207,  1.02460647,  1.02428672, -0.02539092, -0.07886488,
#           0.11036264, -1.04034002,  0.04391191,  0.02270766, -0.94167942]),
#   14.193203802762943,
#   1000398),
#  (array([-3.92242743e-04,  9.21123751e-01, -1.20726319e-01, -8.95596634e-02,
#           9.68438067e-01, -2.93042441e-02,  1.06273000e+00,  5.78151233e-02,
#          -3.47517733e-02,  5.93472458e-03]), 10.459235602181106, 1000398),
#  (array([-9.70536888e-01, -2.46724380e-03,  7.05904228e-04,  2.00926400e+00,
#           8.99825757e-02, -1.40626027e-03,  9.97911780e-01, -9.81935670e-01,
# ...

# %%
print(f"Mean fitness Rastrigin (d=10, n = 1024): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Rastrigin (d=10, n = 1024): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Rastrigin (d=10, n = 1024): 11.525988517510317
# Stddev fitness Rastrigin (d=10, n = 1024): 1.4790318342648454

# %% [markdown]
# ### Rosenbrock

# %% [markdown]
# #### d = 2

# %% [markdown]
# ##### popsize = 32

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Rosenbrock#@param
seed_number = 19520925#@param
popsize = 32#@param
bound_lower = -3#@param
bound_upper = 3#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([0.
#          -1.76001589e-08, -1.91966552e-09,  2.17171827e-08, -8.16217791e-09,
#           8.15674398e-09, -2.77489105e-09]), 0.007396040334114895, 1000030),
#  (array([ 0.00138514, -0.00131179,  0.00063795, -0.00082915,  0.00274931,
#           0.00011627, -0.00470248, -0.00534393, -0.00788127, -0.00295097]),
#   9.584265859285956e-06,
#   182158),
#  (array([ 3.14002263e+00,  4.43844447e+00, -2.52064031e-09,  2.05050768e-08,
# ...

# %%
print(f"Mean fitness Griewank (d=10, n = 32): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Griewank (d=10, n = 32): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Griewank (d=10, n = 32): 0.004934467102705275
# Stddev fitness Griewank (d=10, n = 32): 0.004122375003349379

# %% [markdown]
# ##### popsize = 64

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Griewank#@param
seed_number = 19520925#@param
popsize = 64#@param
bound_lower = -600#@param
bound_upper = 600#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-3.48804576e-05,  6.57420356e-04,  5.37501238e-03,  3.73648511e-03,
#          -3.41722750e-03,  3.08129713e-03,  4.09212256e-05,  1.53119307e-03,
#          -2.36872814e-03, -5.54312756e-04]), 9.119774761590094e-06, 476253),
#  (array([ 0.00104325, -0.00096015,  0.00136086, -0.00469854, -0.00257471,
#          -0.00493536, -0.00336966,  0.00324778, -0.00238518,  0.0034689 ]),
#   8.947700423922456e-06,
#   491463),
#  (array([ 0.00159599, -0.00073857,  0.0007291 ,  0.00313678,  0.00103469,
#           0.00027167, -0.00179395, -0.00104853, -0.00341532, -0.00258296]),
#   4.13120156028679e-06,
#   416908),
#  (array([ 0.00291088,  0.00140984, -0.00116556,  0.00330567,  0.00250897,
#           0.00069143, -0.00378763,  0.00322495,  0.00036236, -0.0036779 ]),
#   9.370537074615548e-06,
#   627573),
#  (array([-0.00128243, -0.00127283, -0.00302184,  0.00179745, -0.00117871,
#          -0.00201045,  0.00265962,  0.00242352, -0.00564006,  0.00550193]),
#   7.806005783872472e-06,
# ...

# %%
print(f"Mean fitness Griewank (d=10, n = 64): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Griewank (d=10, n = 64): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Griewank (d=10, n = 64): 0.0007468365983507197
# Stddev fitness Griewank (d=10, n = 64): 0.0022164016948546528

# %% [markdown]
# ##### popsize = 128

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Griewank#@param
seed_number = 19520925#@param
popsize = 128#@param
bound_lower = -600#@param
bound_upper = 600#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([ 0.0017193 ,  0.0034425 ,  0.00352381,  0.0012544 , -0.00093398,
#          -0.00289392, -0.00160491,  0.00377063, -0.00358519,  0.00044875]),
#   9.305739815501646e-06,
#   889066),
#  (array([ 3.24762884, -0.18414418, -5.02815117,  0.3145121 , -0.02226798,
#          -0.12604466, -0.42405759, -0.12239208,  0.57537624, -0.04768112]),
#   0.07425022875888077,
#   1000006),
#  (array([ 3.26465552,  0.18566278, -0.06965329, -6.11262429,  6.90562165,
#          -7.63283053, -0.16991484,  0.16850128, -0.44954458,  0.15812306]),
#   0.07662028628940654,
#   1000006),
#  (array([-3.12184836, -4.36789318, -0.16267803, -0.17968065, -0.38711785,
#          -7.6691727 , -0.47569316,  0.08817291, -0.37400706, -9.91615704]),
#   0.095145812816538,
#   1000006),
#  (array([ 6.30949498, -4.5860714 ,  5.42494772, -6.1118495 , -0.28091698,
#          -0.23420788, -7.89580057, -0.26236855,  0.3077411 , -0.60630136]),
#   0.10794486390304758,
#   1000006),
# ...

# %%
print(f"Mean fitness Griewank (d=10, n = 128): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Griewank (d=10, n = 128): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Griewank (d=10, n = 128): 0.07121922053399315
# Stddev fitness Griewank (d=10, n = 128): 0.03736957510560473

# %% [markdown]
# ##### popsize = 256

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Griewank#@param
seed_number = 19520925#@param
popsize = 256#@param
bound_lower = -600#@param
bound_upper = 600#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([
d=2, n = 1024): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley (d=2, n = 1024): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley (d=2, n = 1024): 5.092867323686079e-06
# Stddev fitness Ackley (d=2, n = 1024): 2.3813579204150385e-06

# %% [markdown]
# #### d = 10

# %% [markdown]
# ##### popsize = 32

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Ackley#@param
seed_number = 19520925#@param
popsize = 32#@param
bound_lower = -33#@param
bound_upper = 433#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-33., 433., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000031),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000031),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., 433.]),
#   19.999999999987384,
#   1000031),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000031),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000031),
#  (array([433., 433., -33., -33., -33., 433., 433., 433., -33., -33.]),
#   20.0,
#   1000031),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000031),
#  (array([-33., -33., 433., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000031),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000031),
# ...

# %%
print(f"Mean fitness Ackley (d=10, n = 32): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley (d=10, n = 32): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley (d=10, n = 32): 19.97757255909541
# Stddev fitness Ackley (d=10, n = 32): 0.01138318832711022

# %% [markdown]
# ##### popsize = 64

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Ackley#@param
seed_number = 19520925#@param
popsize = 64#@param
bound_lower = -33#@param
bound_upper = 433#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000024),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000024),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000024),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000024),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000024),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000024),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000024),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000024),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000024),
# ...

# %%
print(f"Mean fitness Ackley (d=10, n = 64): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley (d=10, n = 64): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley (d=10, n = 64): 19.972792639249043
# Stddev fitness Ackley (d=10, n = 64): 0.0

# %% [markdown]
# ##### popsize = 128

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Ackley#@param
seed_number = 19520925#@param
popsize = 128#@param
bound_lower = -33#@param
bound_upper = 433#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000007),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000007),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000007),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000007),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000007),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000007),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000007),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000007),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000007),
# ...

# %%
print(f"Mean fitness Ackley (d=10, n = 128): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley (d=10, n = 128): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley (d=10, n = 128): 19.972792639249043
# Stddev fitness Ackley (d=10, n = 128): 0.0

# %% [markdown]
# ##### popsize = 256

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Ackley#@param
seed_number = 19520925#@param
popsize = 256#@param
bound_lower = -33#@param
bound_upper = 433#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000243),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000243),
#  (array([-33., -33., -33., -33., -33., -33., 433., -33., -33., -33.]),
#   19.972792639249043,
#   1000243),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000243),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000243),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000243),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000243),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000243),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000243),
# ...

# %%
print(f"Mean fitness Ackley (d=10, n = 256): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley (d=10, n = 256): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley (d=10, n = 256): 19.972792639249043
# Stddev fitness Ackley (d=10, n = 256): 0.0

# %% [markdown]
# ##### popsize = 512

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Ackley#@param
seed_number = 19520925#@param
popsize = 512#@param
bound_lower = -33#@param
bound_upper = 433#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000349),
#  (array([-33.        ,   9.02292315, -33.        , -33.        ,
#          -33.        , -33.        , -33.        , -33.        ,
#          -33.        , -33.        ]), 19.965616240608238, 1000349),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000349),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000349),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000349),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000349),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000349),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000349),
# ...

# %%
print(f"Mean fitness Ackley (d=10, n = 512): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley (d=10, n = 512): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley (d=10, n = 512): 19.97207499938496
# Stddev fitness Ackley (d=10, n = 512): 0.002152919592241531

# %% [markdown]
# ##### popsize = 1024

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Ackley#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -33#@param
bound_upper = 433#@param

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000399),
#  (array([-16.96613957, -33.        , -33.        , -33.        ,
#          -33.        , -33.        , -33.        , -33.        ,
#          -33.        , -33.        ]), 19.971277245976214, 1000399),
#  (array([-33.        , -33.        , -33.        ,  14.00318354,
#          -33.        , -33.        , -33.        , -33.        ,
#          -33.        , -33.        ]), 19.964186117903072, 1000399),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000399),
#  (array([-33., -33., -33., -33., -33., -33., -33., -33., -33., -33.]),
#   19.972792639249043,
#   1000399),
#  (array([-33.        , -33.        , -33.        , -33.        ,
#          -33.        , -33.        , -33.        , -33.        ,
#          -33.        ,  15.01254534]), 19.96530611814946, 1000399),
# ...

# %%
print(f"Mean fitness Ackley (d=10, n = 1024): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley (d=10, n = 1024): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley (d=10, n = 1024): 19.971031795677202
# Stddev fitness Ackley (d=10, n = 1024): 0.0031845081846284015

# %% [markdown]
# # Evolution Strategies (ES)

# %%
def ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension):
    eps = 0.00001

    bound_lower, bound_upper = np.asarray(bounds).T

    diff = np.fabs(bound_lower - bound_upper)

    mu = bound_lower + diff * np.random.rand(dimension)
    mu_fitness = test_function(mu)
    num_eval = 0

    results = []
    all_pops = []
    results.append((np.copy(mu), mu_fitness, num_eval))
    generation_count = 0
    sigma = sigma_init

    while True:
        if num_eval > max_evals:
            break
        epsilon = np.random.randn(popsize, dimension)
        offspring = mu + sigma * epsilon
        offspring = np.clip(offspring, bound_lower, bound_upper)
        offspring_fitness = np.asarray([test_function(offspring[i]) for i in range(popsize)])
        num_eval += popsize
        
        best_idx = offspring_fitness.argmin()
        best_fitness = offspring_fitness[best_idx]
        best_offspring = offspring[best_idx]

        if best_fitness <= mu_fitness:
            mu = best_offspring.copy()
            mu_fitness = best_fitness
            sigma *= c_inc 
        else:
            sigma *= c_dec
        
        results.append((np.copy(mu), mu_fitness, num_eval))
        all_pops.append(np.copy(offspring))
        if abs(mu_fitness) < eps:
            break
        generation_count += 1

    return results, all_pops, generation_count

# %%
sigma_init=1.0#@param
c_inc = 1.1#@param
c_dec = 0.6#@param

# %% [markdown]
# ### Test algo

# %%
dimension = 2#@param
test_function = Griewank#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -600#@param
bound_upper = 600#@param
popsize = 32#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
all_results.append(results)
seed_number += 1

# %%
results[-1]
# Out:
# (array([514.9551904 , 275.17157026]), 85.27955499699866, 100001)

# %% [markdown]
# ### Sphere

# %% [markdown]
# #### d = 2

# %% [markdown]
# ##### popsize = 32

# %%
dimension = 2#@param
test_function = Sphere#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 32#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([0.00118   , 0.00123659]), 2.9215406144448186e-06, 641),
#  (array([ 0.00059869, -0.00096147]), 1.282850613176499e-06, 481),
#  (array([ 0.00045676, -0.00136017]), 2.058693341682349e-06, 609),
#  (array([-7.42609307e-05, -2.03464838e-03]), 4.145308698843923e-06, 673),
#  (array([0.00086923, 0.00181803]), 4.060812433454911e-06, 801),
#  (array([-0.00227772, -0.00036742]), 5.323010698237285e-06, 609),
#  (array([ 0.00146599, -0.00179384]), 5.367012071186842e-06, 769),
#  (array([ 0.00141456, -0.00064664]), 2.4191300518454923e-06, 609),
#  (array([-0.00163457, -0.0022625 ]), 7.790694953994086e-06, 641),
#  (array([ 1.82762136e-03, -5.37351853e-05]), 3.343087297573989e-06, 641)]

# %%
print(f"Mean fitness Sphere - ES (d=2, n = 32): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Sphere - ES (d=2, n = 32): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Sphere - ES (d=2, n = 32): 3.871214077444019e-06
# Stddev fitness Sphere - ES (d=2, n = 32): 1.8191408204428832e-06

# %% [markdown]
# ##### popsize = 64

# %%
dimension = 2#@param
test_function = Sphere#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 64#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-0.00167773, -0.0011952 ]), 4.24327977980794e-06, 961),
#  (array([-0.00098017,  0.00024821]), 1.0223482899244404e-06, 1089),
#  (array([0.00203611, 0.00219453]), 8.961728685469633e-06, 1281),
#  (array([ 0.00117784, -0.0004761 ]), 1.6139822167904522e-06, 1089),
#  (array([ 8.96696760e-05, -1.34076155e-03]), 1.8056821813752326e-06, 1345),
#  (array([0.00085701, 0.00195022]), 4.5378287106131936e-06, 1089),
#  (array([-0.0008574 , -0.00143435]), 2.7925093921116814e-06, 1281),
#  (array([ 0.00070745, -0.0008895 ]), 1.2916970858792638e-06, 1153),
#  (array([0.00105437, 0.0028119 ]), 9.018497777400165e-06, 1665),
#  (array([ 0.00028791, -0.00065633]), 5.136646629450764e-07, 1217)]

# %%
print(f"Mean fitness Sphere - ES (d=2, n = 64): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Sphere - ES (d=2, n = 64): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Sphere - ES (d=2, n = 64): 3.5801218782317078e-06
# Stddev fitness Sphere - ES (d=2, n = 64): 2.978448144158677e-06

# %% [markdown]
# ##### popsize = 128

# %%
dimension = 2#@param
test_function = Sphere#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array
#  (array([-0.0011995 , -0.00091356,  0.00115411, -0.0006253 , -0.00027934,
#           0.00046934,  0.00142224,  0.00045136,  0.00097876, -0.00052984]),
#   7.75988494734749e-06,
#   27137),
#  (array([-0.00148339, -0.00052337, -0.00025947, -0.00019494, -0.0006691 ,
#          -0.00070479,  0.00034499,  0.00023527, -0.0004505 , -0.00096205]),
#   4.826973602464975e-06,
#   25601),
#  (array([ 0.00089757,  0.00093909,  0.0003759 ,  0.00053827, -0.00010957,
# ...

# %%
print(f"Mean fitness Sphere - ES (d=10, n = 512): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Sphere - ES (d=10, n = 512): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Sphere - ES (d=10, n = 512): 6.488571259856757e-06
# Stddev fitness Sphere - ES (d=10, n = 512): 2.0512037190832667e-06

# %% [markdown]
# ##### popsize = 1024

# %%
dimension = 10#@param
test_function = Sphere#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-6.80383664e-04,  7.99703422e-05,  5.20513205e-04,  2.38387558e-04,
#           2.59274279e-04,  1.38928470e-04,  6.24109193e-05, -2.59610849e-03,
#          -6.00351734e-04,  1.63259380e-04]), 8.014354328816684e-06, 50177),
#  (array([-7.31422396e-04,  2.17635695e-04,  1.58368826e-03, -1.60759626e-03,
#          -2.41861816e-04, -8.44337506e-05, -8.36124759e-04, -4.60222674e-04,
#           1.30243874e-03,  8.01807972e-04]), 8.990556672323928e-06, 45057),
#  (array([ 2.49931809e-05, -1.47066695e-03,  4.57961728e-04,  5.14879075e-04,
#           2.36332507e-04,  1.56692819e-03, -4.59248705e-04,  1.87896938e-04,
#          -1.16856493e-03,  6.70899140e-04]), 7.211296638279626e-06, 47105),
#  (array([ 8.48273983e-04,  2.45806016e-04, -8.32381528e-04, -4.78572757e-04,
#           9.80315894e-04,  8.61910656e-05,  5.15435186e-04, -1.05119802e-03,
#          -2.13225770e-03,  1.03671917e-03]), 9.662328621476622e-06, 45057),
# ...

# %%
print(f"Mean fitness Sphere - ES (d=10, n = 1024): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Sphere - ES (d=10, n = 1024): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Sphere - ES (d=10, n = 1024): 7.558094406788742e-06
# Stddev fitness Sphere - ES (d=10, n = 1024): 1.5147941499988597e-06

# %% [markdown]
# ### Rastrigin

# %% [markdown]
# #### d = 2

# %% [markdown]
# ##### popsize = 32

# %%
dimension = 2#@param
test_function = Rastrigin#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 32#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-1.98991223, -2.9848557 ]), 12.934432432041095, 100001),
#  (array([-9.94958639e-01, -1.43458024e-09]), 0.9949590570932898, 100001),
#  (array([ 7.55502718e-10, -9.94958636e-01]), 0.9949590570932898, 100001),
#  (array([-0.99495864, -1.98991223]), 4.974790247647376, 100001),
#  (array([-6.75725848e-10,  9.94958639e-01]), 0.9949590570932898, 100001),
#  (array([-0.99495864,  0.99495864]), 1.9899181141865796, 100001),
#  (array([-9.94958636e-01,  1.05030279e-09]), 0.9949590570932898, 100001),
#  (array([-9.94958639e-01, -1.55775825e-09]), 0.9949590570932898, 100001),
#  (array([1.98991223e+00, 5.49264954e-10]), 3.9798311905540853, 100001),
#  (array([0.99495864, 1.98991223]), 4.974790247647376, 100001)]

# %%
print(f"Mean fitness Rastrigin - ES (d=2, n = 32): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Rastrigin - ES (d=2, n = 32): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Rastrigin - ES (d=2, n = 32): 3.3828557517542963
# Stddev fitness Rastrigin - ES (d=2, n = 32): 3.565221395879575

# %% [markdown]
# ##### popsize = 64

# %%
dimension = 2#@param
test_function = Rastrigin#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 64#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([
@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -3#@param
bound_upper = 3#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([0.99969916, 0.99929557, 0.99909834, 0.99814023, 0.99656543,
#          0.99305182, 0.98618854, 0.97239711, 0.94533853, 0.89348337]),
#   0.004052374920092371,
#   1000449),
#  (array([0.99986067, 0.99966958, 0.99928978, 0.99865866, 0.99689643,
#          0.99345719, 0.98693423, 0.97383331, 0.94785486, 0.89773814]),
#   0.00373696374578078,
#   1000449),
#  (array([-0.9927557 ,  0.99609891,  0.99697348,  0.99672269,  0.99573641,
#           0.99220567,  0.98451197,  0.9689908 ,  0.93920277,  0.88211312]),
#   3.990802751738865,
#   1000449),
#  (array([1.00007359, 0.99960993, 0.99932388, 0.99845367, 0.99698239,
#          0.99392021, 0.98767386, 0.97543495, 0.95126287, 0.9043776 ]),
#   0.0032506941090411526,
#   1000449),
#  (array([-0.99309226,  0.996082  ,  0.99730157,  0.99707425,  0.9955152 ,
#           0.99176418,  0.98408473,  0.968104  ,  0.93764616,  0.8790139 ]),
#   3.9909169750833695,
#   1000449),
# ...

# %%
print(f"Mean fitness Rosenbrock - ES (d=10, n = 1024): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Rosenbrock - ES (d=10, n = 1024): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Rosenbrock - ES (d=10, n = 1024): 0.8014577529014151
# Stddev fitness Rosenbrock - ES (d=10, n = 1024): 1.5947011983551562

# %% [markdown]
# ### Griewank

# %% [markdown]
# #### d = 2

# %% [markdown]
# ##### popsize = 32

# %%
dimension = 2#@param
test_function = Griewank#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -600#@param
bound_upper = 600#@param
popsize = 32#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([ 6.28004528e+00, -8.56142444e-09]), 0.009864672061006163, 100001),
#  (array([-131.87689199, -470.46476124]), 59.74170509117157, 100001),
#  (array([ 386.20348004, -554.7763792 ]), 114.33713199404117, 100001),
#  (array([-370.52140721,   62.13710615]), 35.305111654152164, 100001),
#  (array([-329.70057566,  155.34304983]), 33.228474388491115, 100001),
#  (array([3.14002263, 4.43844448]), 0.007396040334114895, 100001),
#  (array([ 430.18069459, -110.95831524]), 49.368511538758895, 100001),
#  (array([521.24002284, -97.64218209]), 70.34350118264908, 100001),
#  (array([-9.42006789, -4.43844443]), 0.027125384395415453, 100001),
#  (array([-326.55892879, -248.54804853]), 42.13386762711594, 100001)]

# %%
print(f"Mean fitness Griewank - ES (d=2, n = 32): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Griewank - ES (d=2, n = 32): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Griewank - ES (d=2, n = 32): 40.45026895731704
# Stddev fitness Griewank - ES (d=2, n = 32): 34.338189659523536

# %% [markdown]
# ##### popsize = 64

# %%
dimension = 2#@param
test_function = Griewank#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -600#@param
bound_upper = 600#@param
popsize = 64#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-160.1410495,  -31.0690089]), 6.65606425106421, 100033),
#  (array([-505.54026642,  -93.20411939]), 66.09936744958164, 100033),
#  (array([-15.70011278,  13.31533289]), 0.10602304950900332, 100033),
#  (array([-339.11860811,  257.42435615]), 45.34914340349269, 100033),
#  (array([ 285.73085497, -510.40278286]), 85.61839350153757, 100033),
#  (array([-3.14002263, -4.43844448]), 0.007396040334114895, 100033),
#  (array([  62.80002054, -230.79795927]), 14.316805441106604, 100033),
#  (array([-6.28004503, 17.75377742]), 0.08874262788901754, 100033),
#  (array([-128.74087585,  -22.19217545]), 4.268874268823563, 100033),
#  (array([3.14002263, 4.43844448]), 0.007396040334114895, 100033)]

# %%
print(f"Mean fitness Griewank - ES (d=2, n = 64): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Griewank - ES (d=2, n = 64): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Griewank - ES (d=2, n = 64): 22.251820607367254
# Stddev fitness Griewank - ES (d=2, n = 64): 30.120195732173826

# %% [markdown]
# ##### popsize = 128

# %%
dimension = 2#@param
test_function = Griewank#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -600#@param
bound_upper = 600#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([
@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -600#@param
bound_upper = 600#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([-1.57001014e+01, -8.87687556e+00,  2.00961485e-09, -6.27062508e+00,
#           1.40145425e+01, -1.53444997e+01, -8.28283983e+00, -8.85031244e+00,
#          -2.81475521e+01, -9.88509143e+00]), 0.45987572771007, 1000449),
#  (array([ 6.28004229e+00, -1.33153211e+01, -1.61707089e-08,  2.79668781e-09,
#           7.00728011e+00,  7.67226081e+00, -2.79228865e-10, -1.77006761e+01,
#           1.87650546e+01, -9.88511937e+00]), 0.27292155578993427, 1000449),
#  (array([6.28004468e+00, 1.47549408e-08, 1.08664938e+01, 1.41513789e-08,
#          1.19808099e-08, 7.67227838e+00, 2.49604123e-08, 1.70657605e-08,
#          9.38255113e+00, 5.30384198e-09]), 0.076296378688123, 1000449),
#  (array([-9.42006296e+00, -8.87687972e+00,  5.43323965e+00,  6.27063091e+00,
#          -6.76396032e-09,  7.67225846e+00, -2.48485877e+01, -1.77006688e+01,
#          -9.38251464e+00,  1.22618837e-08]), 0.32956922149495904, 1000449),
# ...

# %%
print(f"Mean fitness Griewank - ES (d=10, n = 1024): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Griewank - ES (d=10, n = 1024): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Griewank - ES (d=10, n = 1024): 0.26594019626713006
# Stddev fitness Griewank - ES (d=10, n = 1024): 0.1296227248287259

# %% [markdown]
# ### Ackley

# %% [markdown]
# #### d = 2

# %% [markdown]
# ##### popsize = 32

# %%
dimension = 2#@param
test_function = Ackley#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 32#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([ 13.        , 412.99999999]), 20.0, 100001),
#  (array([350., 391.]), 20.0, 100001),
#  (array([288.,  60.]), 20.0, 100001),
#  (array([350.,  17.]), 20.0, 100001),
#  (array([320.00000001,  -2.99999999]), 20.0, 100001),
#  (array([160.99999999,  86.00000001]), 19.999999999876877, 100001),
#  (array([401., 125.]), 20.0, 100001),
#  (array([ 73., 139.]), 19.999999995448782, 100001),
#  (array([295., 407.]), 20.0, 100001),
#  (array([315.        ,  60.99999999]), 20.0, 100001)]

# %%
print(f"Mean fitness Ackley - ES (d=2, n = 32): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley - ES (d=2, n = 32): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley - ES (d=2, n = 32): 19.999999999532566
# Stddev fitness Ackley - ES (d=2, n = 32): 1.3617561767445815e-09

# %% [markdown]
# ##### popsize = 64

# %%
dimension = 2#@param
test_function = Ackley#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 64#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([ 14.99999999, 354.        ]), 20.0, 100033),
#  (array([ 76., 202.]), 19.999999999998888, 100033),
#  (array([428.00000001, 333.        ]), 20.0, 100033),
#  (array([117.99999999,  32.        ]), 19.99999938073189, 100033),
#  (array([183.,  94.]), 19.99999999999537, 100033),
#  (array([234.,  23.]), 19.999999999999925, 100033),
#  (array([ 91., 177.]), 19.99999999998805, 100033),
#  (array([ 61., 394.]), 20.0, 100033),
#  (array([298.        ,  82.99999999]), 20.0, 100033),
#  (array([148., 155.]), 19.999999999998625, 100033)]

# %%
print(f"Mean fitness Ackley - ES (d=2, n = 64): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley - ES (d=2, n = 64): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley - ES (d=2, n = 64): 19.999999938071277
# Stddev fitness Ackley - ES (d=2, n = 64): 1.85779795137353e-07

# %% [markdown]
# ##### popsize = 128

# %%
dimension = 2#@param
test_function = Ackley#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([177., 229.]), 20.0, 100097),
#  (array([413.99999999, 328.        ]), 20.0, 100097),
#  (array([363.00000001, 321.        ]), 20.0, 100097),
#  (array([ 98.00000001, 230.99999999]), 19.999999999999993, 100097),
#  (array([388.00000001, 112.99999999]), 20.0, 100097),
#  (array([378.00000001, 364.        ]), 20.0, 100097),
#  (array([373.        , 280.00000001]), 20.0, 100097),
#  (array([108.        , 341.00000001]), 20.0, 100097),
#  (array([60.99999979, 59.9999998 ]), 19.999888855668978, 100097),
#  (array([387.99999999,  57.        ]), 20.0, 100097)]

# %%
print(f"Mean fitness Ackley - ES (d=2, n = 128): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley - ES (d=2, n = 128): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley - ES (d=2, n = 128): 19.9999888855669
# Stddev fitness Ackley - ES (d=2, n = 128): 3.3343299306428284e-05

# %% [markdown]
# ##### popsize = 256

# %%
dimension = 2#@param
test_function = Ackley#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 256#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([185., 366.]), 20.0, 100097),
#  (array([227.00000001, 269.        ]), 20.0, 100097),
#  (array([-16.99999984,  76.99999927]), 19.999712977273955, 100097),
#  (array([191.00000001, 235.        ]), 20.0, 100097),
#  (array([302.        , 368.00000001]), 20.0, 100097),
#  (array([227.99999999,  58.99999999]), 19.999999999999932, 100097),
#  (array([-15.99999999, 400.        ]), 20.0, 100097),
#  (array([166.00000001,   1.        ]), 19.999999998725407, 100097),
#  (array([ 17.        , 101.99999998]), 19.999991088969608, 100097),
#  (array([420.00000001,  51.        ]), 20.0, 100097)]

# %%
print(f"Mean fitness Ackley - ES (d=2, n = 256): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley - ES (d=2, n = 256): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley - ES (d=2, n = 256): 19.999970406496892
# Stddev fitness Ackley - ES (d=2, n = 256): 8.58508575773256e-05

# %% [markdown]
# ##### popsize = 512

# %%
dimension = 2#@param
test_function = Ackley#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 512#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([228.00000001, 158.        ]), 20.0, 100353),
#  (array([389., 167.]), 20.0, 100353),
#  (array([339., -29.]), 20.0, 100353),
#  (array([ -2., 261.]), 19.999999999999996, 100353),
#  (array([239.99999999, 212.        ]), 20.0, 100353),
#  (array([ 17.        , 290.99999999]), 20.0, 100353),
#  (array([ 88., 116.]), 19.999999977177705, 100353),
#  (array([ 97.99999999, 310.        ]), 20.0, 100353),
#  (array([429., 224.]), 20.0, 100353),
#  (array([ 53.99999999, 135.99999999]), 19.99999997940522, 100353)]

# %%
print(f"Mean fitness Ackley - ES (d=2, n = 512): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley - ES (d=2, n = 512): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley - ES (d=2, n = 512): 19.999999995658293
# Stddev fitness Ackley - ES (d=2, n = 512): 8.697688324467569e-09

# %% [markdown]
# ##### popsize = 1024

# %%
dimension = 2#@param
test_function = Ackley#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([280.99999999, 309.        ]), 20.0, 100353),
#  (array([418.        , 236.99999999]), 20.0, 100353),
#  (array([268.99999999, 268.        ]), 20.0, 100353),
#  (array([170.00000001, 314.        ]), 20.0, 100353),
#  (array([399.        ,  46.00000001]), 20.0, 100353),
#  (array([245., 192.]), 20.0, 100353),
#  (array([149.        , 282.99999999]), 20.0, 100353),
#  (array([337.,  87.]), 20.0, 100353),
#  (array([220.        ,  38.00000001]), 19.999999999999613, 100353),
#  (array([186., 120.]), 19.999999999999492, 100353)]

# %%
print(f"Mean fitness Ackley - ES (d=2, n = 1024): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley - ES (d=2, n = 1024): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley - ES (d=2, n = 1024): 19.999999999999908
# Stddev fitness Ackley - ES (d=2, n = 1024): 1.811047850635569e-13

# %% [markdown]
# #### d = 10

# %% [markdown]
# ##### popsize = 32

# %%
dimension = 10#@param
test_function = Ackley#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 32#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([146.99999999, 353.        , 245.        , 108.        ,
#          406.        ,  78.        , 131.99999999, 352.        ,
#           31.        , 301.00000001]), 20.0, 1000001),
#  (array([341.99999999,  75.99999999, 299.00000001, 230.        ,
#            3.        , 325.        , 277.99999999, 276.        ,
#           98.99999999, 234.        ]), 20.0, 1000001),
#  (array([296.00000001, 255.99999999,  47.00000001, -10.        ,
#          179.99999999, 171.99999999, -33.        , 362.        ,
#          330.99999999,  88.99999999]), 20.0, 1000001),
#  (array([ 35.00000001,   5.        , 262.        , 240.        ,
#          322.        ,  -7.        , 157.00000001, -30.        ,
#          364.00000001, 299.        ]), 20.0, 1000001),
#  (array([ 53.00000001, 320.        , 306.99999999, -30.        ,
#          306.        , 109.99999999, 317.        , 339.99999999,
#          -30.        , 356.00000001]), 20.0, 1000001),
# ...

# %%
print(f"Mean fitness Ackley - ES (d=10, n = 32): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley - ES (d=10, n = 32): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley - ES (d=10, n = 32): 20.0
# Stddev fitness Ackley - ES (d=10, n = 32): 0.0

# %% [markdown]
# ##### popsize = 64

# %%
dimension = 10#@param
test_function = Ackley#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 64#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([130.00000001,  83.00000001, 155.        , 146.        ,
#          123.        , 173.99999999,  23.        , 376.        ,
#          189.99999999, 322.        ]), 20.0, 1000001),
#  (array([384.99999999,  15.        , 148.        , 368.00000001,
#          102.00000001, 375.        , 432.00000001,  17.99999999,
#          108.00000001, 393.        ]), 20.0, 1000001),
#  (array([252.        , 224.00000001, 312.        , 424.        ,
#          207.        , 212.99999999, 218.00000001,  96.        ,
#          290.        ,  86.        ]), 20.0, 1000001),
#  (array([261.        , 426.00000001, 404.00000001, 173.        ,
#           48.        , -22.99999999, 225.00000001, 340.        ,
#          144.        , 300.        ]), 20.0, 1000001),
#  (array([101.        , 259.        ,  37.        ,  22.99999999,
#          348.99999999,  97.00000001, 397.00000001, 221.        ,
#          253.        , 419.        ]), 20.0, 1000001),
# ...

# %%
print(f"Mean fitness Ackley - ES (d=10, n = 64): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley - ES (d=10, n = 64): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley - ES (d=10, n = 64): 19.999999999999996
# Stddev fitness Ackley - ES (d=10, n = 64): 7.53644380168212e-15

# %% [markdown]
# ##### popsize = 128

# %%
dimension = 10#@param
test_function = Ackley#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([385.        , 270.        , 195.        , 418.00000001,
#          163.99999999, 301.        , 417.99999999, 214.00000001,
#          334.        , 222.99999999]), 20.0, 1000065),
#  (array([224.        ,  63.99999999,  53.        , 364.        ,
#          232.00000001, -13.99999999, -29.        , -29.        ,
#          417.        , 408.        ]), 20.0, 1000065),
#  (array([418.        , 333.00000001,  35.        , -11.        ,
#          353.00000001,  73.        , 109.        , 362.        ,
#          354.00000001, 220.99999999]), 20.0, 1000065),
#  (array([300.        ,  21.99999999, 110.        ,  53.        ,
#           50.99999999, 339.99999999, 308.        ,  50.99999999,
#          342.        ,  26.        ]), 20.0, 1000065),
#  (array([319.        , 334.        , 271.        ,  87.        ,
#          285.        , 317.00000001,  25.99999999, 254.        ,
#          203.99999999,  82.00000001]), 20.0, 1000065),
# ...

# %%
print(f"Mean fitness Ackley - ES (d=10, n = 128): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley - ES (d=10, n = 128): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley - ES (d=10, n = 128): 20.0
# Stddev fitness Ackley - ES (d=10, n = 128): 0.0

# %% [markdown]
# ##### popsize = 256

# %%
dimension = 10#@param
test_function = Ackley#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 256#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([ 85.99999999, 356.        , 404.        ,  37.        ,
#          432.        , 138.00000001, 399.00000001, 318.        ,
#          296.99999999, 116.        ]), 20.0, 1000193),
#  (array([385.        , 102.00000001, 387.        , 328.99999999,
#           94.        , 413.00000001, 101.        , 333.        ,
#          380.        , 161.        ]), 20.0, 1000193),
#  (array([194.        , 183.        , 158.99999999,  -9.        ,
#          405.        , 281.00000001,  95.99999999, 291.00000001,
#          -28.        , 287.        ]), 20.0, 1000193),
#  (array([ 64.        , 391.        , 146.        , -17.99999999,
#          278.        , 194.        , 226.        , 356.        ,
#          366.        , 396.        ]), 20.0, 1000193),
#  (array([322.00000001, 386.99999999,  48.        , 201.99999999,
#          165.        , 327.        , 214.        , 318.        ,
#          382.99999999, 282.99999999]), 20.0, 1000193),
# ...

# %%
print(f"Mean fitness Ackley - ES (d=10, n = 256): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley - ES (d=10, n = 256): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley - ES (d=10, n = 256): 20.0
# Stddev fitness Ackley - ES (d=10, n = 256): 0.0

# %% [markdown]
# ##### popsize = 512

# %%
dimension = 10#@param
test_function = Ackley#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 512#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([389.00000001, 380.        , 388.00000001,  27.        ,
#          123.        , 312.        ,  10.        ,  77.00000001,
#          396.00000001,  70.99999999]), 20.0, 1000449),
#  (array([245.        ,  88.        , 279.99999999, 346.        ,
#          301.99999999, 268.00000001,  29.        , 125.        ,
#          199.        , 346.        ]), 20.0, 1000449),
#  (array([295.99999999, 179.        ,  51.00000001,  -9.        ,
#          323.        ,  79.99999999, 371.        , 270.        ,
#           66.        , 183.99999999]), 20.0, 1000449),
#  (array([301.00000001, 103.00000001, 376.        ,  98.99999999,
#          349.        , 177.00000001,  65.        , 352.99999999,
#          349.99999999,   4.00000001]), 20.0, 1000449),
#  (array([176.        ,  61.00000001,  19.        , 314.        ,
#          332.        , 388.        , 210.        , 386.00000001,
#           71.99999999, 248.99999999]), 20.0, 1000449),
# ...

# %%
print(f"Mean fitness Ackley - ES (d=10, n = 512): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley - ES (d=10, n = 512): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley - ES (d=10, n = 512): 20.0
# Stddev fitness Ackley - ES (d=10, n = 512): 0.0

# %% [markdown]
# ##### popsize = 1024

# %%
dimension = 10#@param
test_function = Ackley#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results[-1])
    seed_number += 1

# %%
all_results
# Out:
# [(array([  4.00000001,  42.00000001, 427.00000001, 415.99999999,
#          -10.        , -29.99999999, 122.        , 389.99999999,
#          428.        , 199.        ]), 20.0, 1000449),
#  (array([171.00000001, 145.        , 297.        , 311.        ,
#           39.        , 115.99999999, 265.        ,  17.        ,
#          174.99999999, 358.99999999]), 20.0, 1000449),
#  (array([ 74.        ,  -7.00000001,  72.        , 402.00000001,
#            9.00000001, 354.00000001, 223.        ,  38.        ,
#          230.        ,  54.00000001]), 20.0, 1000449),
#  (array([330.        , 217.        , 332.00000001, 237.00000001,
#          128.        ,  41.        , 350.        , 348.99999999,
#           24.00000001,  55.99999999]), 20.0, 1000449),
#  (array([347.99999999, 409.        , 187.99999999, 219.99999999,
#          140.        , 179.99999999,  44.        , 379.        ,
#          349.00000001, 319.        ]), 20.0, 1000449),
# ...

# %%
print(f"Mean fitness Ackley - ES (d=10, n = 1024): {np.mean([all_results[i][1] for i in range(len(all_results))])}")
print(f"Stddev fitness Ackley - ES (d=10, n = 1024): {np.std([all_results[i][1] for i in range(len(all_results))])}")
# Out:
# Mean fitness Ackley - ES (d=10, n = 1024): 20.0
# Stddev fitness Ackley - ES (d=10, n = 1024): 0.0

# %% [markdown]
# # Cross Entropy Method

# %% [markdown]
# # Plot

# %% [markdown]
# ## Sphere

# %% [markdown]
# ### d = 2

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Sphere#@param
seed_number = 19520925#@param
popsize = 128#@param
bound_lower = -6
bound_upper = 6

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_128 = []
plt_std_de_128 = []
plt_eval_de_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_128.append(np.mean(fitness))
    plt_std_de_128.append(np.std(fitness))
    plt_eval_de_128.append(np.mean(eval))

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Sphere#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -6
bound_upper = 6

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_1024 = []
plt_std_de_1024 = []
plt_eval_de_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_1024.append(np.mean(fitness))
    plt_std_de_1024.append(np.std(fitness))
    plt_eval_de_1024.append(np.mean(eval))

# %%
dimension = 2#@param
test_function = Sphere#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_128 = []
plt_std_es_128 = []
plt_eval_es_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_128.append(np.mean(fitness))
    plt_std_es_128.append(np.std(fitness))
    plt_eval_es_128.append(np.mean(eval))

# %%
dimension = 2#@param
test_function = Sphere#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_1024 = []
plt_std_es_1024 = []
plt_eval_es_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_1024.append(np.mean(fitness))
    plt_std_es_1024.append(np.std(fitness))
    plt_eval_es_1024.append(np.mean(eval))

# %%
error1_de_128, error2_de_128 = [], []
for i in range(len(plt_fitness_de_128)):
    error1_de_128.append(plt_fitness_de_128[i] + plt_std_de_128[i])
    error2_de_128.append(plt_fitness_de_128[i] - plt_std_de_128[i])

error1_de_1024, error2_de_1024 = [], []
for i in range(len(plt_fitness_de_1024)):
    error1_de_1024.append(plt_fitness_de_1024[i] + plt_std_de_1024[i])
    error2_de_1024.append(plt_fitness_de_1024[i] - plt_std_de_1024[i])

error1_es_128, error2_es_128 = [], []
for i in range(len(plt_fitness_es_128)):
    error1_es_128.append(plt_fitness_es_128[i] + plt_std_es_128[i])
    error2_es_128.append(plt_fitness_es_128[i] - plt_std_es_128[i])

error1_es_1024, error2_es_1024 = [], []
for i in range(len(plt_fitness_es_1024)):
    error1_es_1024.append(plt_fitness_es_1024[i] + plt_std_es_1024[i])
    error2_es_1024.append(plt_fitness_es_1024[i] - plt_std_es_1024[i])

plt.figure(figsize=(12, 6))
plt.xlim(left=0, right=2200)
plt.ylim(-1, 10)

# DE 128
plt.plot(plt_eval_de_128, plt_fitness_de_128, label='DE-128')
plt.fill_between(plt_eval_de_128, error1_de_128, error2_de_128, alpha=0.2)

# DE 1024
plt.plot(plt_eval_de_1024, plt_fitness_de_1024, label='DE-1024')
plt.fill_between(plt_eval_de_1024, error1_de_1024, error2_de_1024, alpha=0.2)

# ES 128
plt.plot(plt_eval_es_128, plt_fitness_es_128,label='ES-128')
plt.fill_between(plt_eval_es_128, error1_es_128, error2_es_128, alpha=0.2)

# ES 1024
plt.plot(plt_eval_es_1024, plt_fitness_es_1024, label='ES-1024')
plt.fill_between(plt_eval_es_1024, error1_es_1024, error2_es_1024, alpha=0.2)

plt.xlabel('Number of function evaluations')
plt.ylabel('Best fitness')
plt.legend()
plt.savefig('Sphere-2d.png')
plt.show()

# %% [markdown]
# ### d = 10

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Sphere#@param
seed_number = 19520925#@param
popsize = 128#@param
bound_lower = -6
bound_upper = 6

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_128 = []
plt_std_de_128 = []
plt_eval_de_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_128.append(np.mean(fitness))
    plt_std_de_128.append(np.std(fitness))
    plt_eval_de_128.append(np.mean(eval))

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Sphere#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -6
bound_upper = 6

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_1024 = []
plt_std_de_1024 = []
plt_eval_de_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_1024.append(np.mean(fitness))
    plt_std_de_1024.append(np.std(fitness))
    plt_eval_de_1024.append(np.mean(eval))

# %%
dimension = 10#@param
test_function = Sphere#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_128 = []
plt_std_es_128 = []
plt_eval_es_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_128.append(np.mean(fitness))
    plt_std_es_128.append(np.std(fitness))
    plt_eval_es_128.append(np.mean(eval))

# %%
dimension = 10#@param
test_function = Sphere#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_1024 = []
plt_std_es_1024 = []
plt_eval_es_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_1024.append(np.mean(fitness))
    plt_std_es_1024.append(np.std(fitness))
    plt_eval_es_1024.append(np.mean(eval))

# %%
error1_de_128, error2_de_128 = [], []
for i in range(len(plt_fitness_de_128)):
    error1_de_128.append(plt_fitness_de_128[i] + plt_std_de_128[i])
    error2_de_128.append(plt_fitness_de_128[i] - plt_std_de_128[i])

error1_de_1024, error2_de_1024 = [], []
for i in range(len(plt_fitness_de_1024)):
    error1_de_1024.append(plt_fitness_de_1024[i] + plt_std_de_1024[i])
    error2_de_1024.append(plt_fitness_de_1024[i] - plt_std_de_1024[i])

error1_es_128, error2_es_128 = [], []
for i in range(len(plt_fitness_es_128)):
    error1_es_128.append(plt_fitness_es_128[i] + plt_std_es_128[i])
    error2_es_128.append(plt_fitness_es_128[i] - plt_std_es_128[i])

error1_es_1024, error2_es_1024 = [], []
for i in range(len(plt_fitness_es_1024)):
    error1_es_1024.append(plt_fitness_es_1024[i] + plt_std_es_1024[i])
    error2_es_1024.append(plt_fitness_es_1024[i] - plt_std_es_1024[i])

plt.figure(figsize=(12, 6))
plt.xlim(left=0, right=8000)
plt.ylim(-1, 170)

# DE 128
plt.plot(plt_eval_de_128, plt_fitness_de_128, label='DE-128')
plt.fill_between(plt_eval_de_128, error1_de_128, error2_de_128, alpha=0.2)

# DE 1024
plt.plot(plt_eval_de_1024, plt_fitness_de_1024, label='DE-1024')
plt.fill_between(plt_eval_de_1024, error1_de_1024, error2_de_1024, alpha=0.2)

# ES 128
plt.plot(plt_eval_es_128, plt_fitness_es_128,label='ES-128')
plt.fill_between(plt_eval_es_128, error1_es_128, error2_es_128, alpha=0.2)

# ES 1024
plt.plot(plt_eval_es_1024, plt_fitness_es_1024, label='ES-1024')
plt.fill_between(plt_eval_es_1024, error1_es_1024, error2_es_1024, alpha=0.2)

plt.xlabel('Number of function evaluations')
plt.ylabel('Best fitness')
plt.legend()
plt.savefig('Sphere-10d.png')
plt.show()

# %% [markdown]
# ## Rastrigin

# %% [markdown]
# ### d = 2

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Rastrigin#@param
seed_number = 19520925#@param
popsize = 128#@param
bound_lower = -6
bound_upper = 6

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_128 = []
plt_std_de_128 = []
plt_eval_de_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_128.append(np.mean(fitness))
    plt_std_de_128.append(np.std(fitness))
    plt_eval_de_128.append(np.mean(eval))

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Rastrigin#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -6
bound_upper = 6

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_1024 = []
plt_std_de_1024 = []
plt_eval_de_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_1024.append(np.mean(fitness))
    plt_std_de_1024.append(np.std(fitness))
    plt_eval_de_1024.append(np.mean(eval))

# %%
dimension = 2#@param
test_function = Rastrigin#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_128 = []
plt_std_es_128 = []
plt_eval_es_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_128.append(np.mean(fitness))
    plt_std_es_128.append(np.std(fitness))
    plt_eval_es_128.append(np.mean(eval))

# %%
dimension = 2#@param
test_function = Rastrigin#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_1024 = []
plt_std_es_1024 = []
plt_eval_es_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_1024.append(np.mean(fitness))
    plt_std_es_1024.append(np.std(fitness))
    plt_eval_es_1024.append(np.mean(eval))

# %%
error1_de_128, error2_de_128 = [], []
for i in range(len(plt_fitness_de_128)):
    error1_de_128.append(plt_fitness_de_128[i] + plt_std_de_128[i])
    error2_de_128.append(plt_fitness_de_128[i] - plt_std_de_128[i])

error1_de_1024, error2_de_1024 = [], []
for i in range(len(plt_fitness_de_1024)):
    error1_de_1024.append(plt_fitness_de_1024[i] + plt_std_de_1024[i])
    error2_de_1024.append(plt_fitness_de_1024[i] - plt_std_de_1024[i])

error1_es_128, error2_es_128 = [], []
for i in range(len(plt_fitness_es_128)):
    error1_es_128.append(plt_fitness_es_128[i] + plt_std_es_128[i])
    error2_es_128.append(plt_fitness_es_128[i] - plt_std_es_128[i])

error1_es_1024, error2_es_1024 = [], []
for i in range(len(plt_fitness_es_1024)):
    error1_es_1024.append(plt_fitness_es_1024[i] + plt_std_es_1024[i])
    error2_es_1024.append(plt_fitness_es_1024[i] - plt_std_es_1024[i])

plt.figure(figsize=(12, 6))
plt.xlim(left=0, right=4000)
plt.ylim(-1, 36)

# DE 128
plt.plot(plt_eval_de_128, plt_fitness_de_128, label='DE-128')
plt.fill_between(plt_eval_de_128, error1_de_128, error2_de_128, alpha=0.2)

# DE 1024
plt.plot(plt_eval_de_1024, plt_fitness_de_1024, label='DE-1024')
plt.fill_between(plt_eval_de_1024, error1_de_1024, error2_de_1024, alpha=0.2)

# ES 128
plt.plot(plt_eval_es_128, plt_fitness_es_128,label='ES-128')
plt.fill_between(plt_eval_es_128, error1_es_128, error2_es_128, alpha=0.2)

# ES 1024
plt.plot(plt_eval_es_1024, plt_fitness_es_1024, label='ES-1024')
plt.fill_between(plt_eval_es_1024, error1_es_1024, error2_es_1024, alpha=0.2)

plt.xlabel('Number of function evaluations')
plt.ylabel('Best fitness')
plt.legend()
plt.savefig('Rastrigin-2d.png')
plt.show()

# %% [markdown]
# ### d = 10

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Rastrigin#@param
seed_number = 19520925#@param
popsize = 128#@param
bound_lower = -6
bound_upper = 6

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_128 = []
plt_std_de_128 = []
plt_eval_de_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_128.append(np.mean(fitness))
    plt_std_de_128.append(np.std(fitness))
    plt_eval_de_128.append(np.mean(eval))

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Rastrigin#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -6
bound_upper = 6

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_1024 = []
plt_std_de_1024 = []
plt_eval_de_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_1024.append(np.mean(fitness))
    plt_std_de_1024.append(np.std(fitness))
    plt_eval_de_1024.append(np.mean(eval))

# %%
dimension = 10#@param
test_function = Rastrigin#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_128 = []
plt_std_es_128 = []
plt_eval_es_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_128.append(np.mean(fitness))
    plt_std_es_128.append(np.std(fitness))
    plt_eval_es_128.append(np.mean(eval))

# %%
dimension = 10#@param
test_function = Rastrigin#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -6#@param
bound_upper = 6#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_1024 = []
plt_std_es_1024 = []
plt_eval_es_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_1024.append(np.mean(fitness))
    plt_std_es_1024.append(np.std(fitness))
    plt_eval_es_1024.append(np.mean(eval))

# %%
error1_de_128, error2_de_128 = [], []
for i in range(len(plt_fitness_de_128)):
    error1_de_128.append(plt_fitness_de_128[i] + plt_std_de_128[i])
    error2_de_128.append(plt_fitness_de_128[i] - plt_std_de_128[i])

error1_de_1024, error2_de_1024 = [], []
for i in range(len(plt_fitness_de_1024)):
    error1_de_1024.append(plt_fitness_de_1024[i] + plt_std_de_1024[i])
    error2_de_1024.append(plt_fitness_de_1024[i] - plt_std_de_1024[i])

error1_es_128, error2_es_128 = [], []
for i in range(len(plt_fitness_es_128)):
    error1_es_128.append(plt_fitness_es_128[i] + plt_std_es_128[i])
    error2_es_128.append(plt_fitness_es_128[i] - plt_std_es_128[i])

error1_es_1024, error2_es_1024 = [], []
for i in range(len(plt_fitness_es_1024)):
    error1_es_1024.append(plt_fitness_es_1024[i] + plt_std_es_1024[i])
    error2_es_1024.append(plt_fitness_es_1024[i] - plt_std_es_1024[i])

plt.figure(figsize=(12, 6))
plt.xlim(left=0, right=400000)
# plt.ylim(-1,)

# DE 128
plt.plot(plt_eval_de_128, plt_fitness_de_128, label='DE-128')
plt.fill_between(plt_eval_de_128, error1_de_128, error2_de_128, alpha=0.2)

# DE 1024
plt.plot(plt_eval_de_1024, plt_fitness_de_1024, label='DE-1024')
plt.fill_between(plt_eval_de_1024, error1_de_1024, error2_de_1024, alpha=0.2)

# ES 128
plt.plot(plt_eval_es_128, plt_fitness_es_128,label='ES-128')
plt.fill_between(plt_eval_es_128, error1_es_128, error2_es_128, alpha=0.2)

# ES 1024
plt.plot(plt_eval_es_1024, plt_fitness_es_1024, label='ES-1024')
plt.fill_between(plt_eval_es_1024, error1_es_1024, error2_es_1024, alpha=0.2)

plt.xlabel('Number of function evaluations')
plt.ylabel('Best fitness')
plt.legend()
plt.savefig('Rastrigin-10d.png')
plt.show()

# %% [markdown]
# ## Rosenbrock

# %% [markdown]
# ### d = 2

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Rosenbrock#@param
seed_number = 19520925#@param
popsize = 128#@param
bound_lower = -3
bound_upper = 3

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_128 = []
plt_std_de_128 = []
plt_eval_de_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_128.append(np.mean(fitness))
    plt_std_de_128.append(np.std(fitness))
    plt_eval_de_128.append(np.mean(eval))

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Rosenbrock#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -3
bound_upper = 3

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_1024 = []
plt_std_de_1024 = []
plt_eval_de_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_1024.append(np.mean(fitness))
    plt_std_de_1024.append(np.std(fitness))
    plt_eval_de_1024.append(np.mean(eval))

# %%
dimension = 2#@param
test_function = Rosenbrock#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -3#@param
bound_upper = 3#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_128 = []
plt_std_es_128 = []
plt_eval_es_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_128.append(np.mean(fitness))
    plt_std_es_128.append(np.std(fitness))
    plt_eval_es_128.append(np.mean(eval))

# %%
dimension = 2#@param
test_function = Rosenbrock#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -3#@param
bound_upper = 3#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_1024 = []
plt_std_es_1024 = []
plt_eval_es_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_1024.append(np.mean(fitness))
    plt_std_es_1024.append(np.std(fitness))
    plt_eval_es_1024.append(np.mean(eval))

# %%
error1_de_128, error2_de_128 = [], []
for i in range(len(plt_fitness_de_128)):
    error1_de_128.append(plt_fitness_de_128[i] + plt_std_de_128[i])
    error2_de_128.append(plt_fitness_de_128[i] - plt_std_de_128[i])

error1_de_1024, error2_de_1024 = [], []
for i in range(len(plt_fitness_de_1024)):
    error1_de_1024.append(plt_fitness_de_1024[i] + plt_std_de_1024[i])
    error2_de_1024.append(plt_fitness_de_1024[i] - plt_std_de_1024[i])

error1_es_128, error2_es_128 = [], []
for i in range(len(plt_fitness_es_128)):
    error1_es_128.append(plt_fitness_es_128[i] + plt_std_es_128[i])
    error2_es_128.append(plt_fitness_es_128[i] - plt_std_es_128[i])

error1_es_1024, error2_es_1024 = [], []
for i in range(len(plt_fitness_es_1024)):
    error1_es_1024.append(plt_fitness_es_1024[i] + plt_std_es_1024[i])
    error2_es_1024.append(plt_fitness_es_1024[i] - plt_std_es_1024[i])

plt.figure(figsize=(12, 6))
plt.xlim(left=0, right=2000)
plt.ylim(-2, 1200)

# DE 128
plt.plot(plt_eval_de_128, plt_fitness_de_128, label='DE-128')
plt.fill_between(plt_eval_de_128, error1_de_128, error2_de_128, alpha=0.2)

# DE 1024
plt.plot(plt_eval_de_1024, plt_fitness_de_1024, label='DE-1024')
plt.fill_between(plt_eval_de_1024, error1_de_1024, error2_de_1024, alpha=0.2)

# ES 128
plt.plot(plt_eval_es_128, plt_fitness_es_128,label='ES-128')
plt.fill_between(plt_eval_es_128, error1_es_128, error2_es_128, alpha=0.2)

# ES 1024
plt.plot(plt_eval_es_1024, plt_fitness_es_1024, label='ES-1024')
plt.fill_between(plt_eval_es_1024, error1_es_1024, error2_es_1024, alpha=0.2)

plt.xlabel('Number of function evaluations')
plt.ylabel('Best fitness')
plt.legend()
plt.savefig('Rosenbrock-2d.png')
plt.show()

# %% [markdown]
# ### d = 10

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Rosenbrock#@param
seed_number = 19520925#@param
popsize = 128#@param
bound_lower = -3
bound_upper = 3

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_128 = []
plt_std_de_128 = []
plt_eval_de_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_128.append(np.mean(fitness))
    plt_std_de_128.append(np.std(fitness))
    plt_eval_de_128.append(np.mean(eval))

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Rosenbrock#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -3
bound_upper = 3

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_1024 = []
plt_std_de_1024 = []
plt_eval_de_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_1024.append(np.mean(fitness))
    plt_std_de_1024.append(np.std(fitness))
    plt_eval_de_1024.append(np.mean(eval))

# %%
dimension = 10#@param
test_function = Rosenbrock#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -3#@param
bound_upper = 3#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_128 = []
plt_std_es_128 = []
plt_eval_es_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_128.append(np.mean(fitness))
    plt_std_es_128.append(np.std(fitness))
    plt_eval_es_128.append(np.mean(eval))

# %%
dimension = 10#@param
test_function = Rosenbrock#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -3#@param
bound_upper = 3#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_1024 = []
plt_std_es_1024 = []
plt_eval_es_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_1024.append(np.mean(fitness))
    plt_std_es_1024.append(np.std(fitness))
    plt_eval_es_1024.append(np.mean(eval))

# %%
error1_de_128, error2_de_128 = [], []
for i in range(len(plt_fitness_de_128)):
    error1_de_128.append(plt_fitness_de_128[i] + plt_std_de_128[i])
    error2_de_128.append(plt_fitness_de_128[i] - plt_std_de_128[i])

error1_de_1024, error2_de_1024 = [], []
for i in range(len(plt_fitness_de_1024)):
    error1_de_1024.append(plt_fitness_de_1024[i] + plt_std_de_1024[i])
    error2_de_1024.append(plt_fitness_de_1024[i] - plt_std_de_1024[i])

error1_es_128, error2_es_128 = [], []
for i in range(len(plt_fitness_es_128)):
    error1_es_128.append(plt_fitness_es_128[i] + plt_std_es_128[i])
    error2_es_128.append(plt_fitness_es_128[i] - plt_std_es_128[i])

error1_es_1024, error2_es_1024 = [], []
for i in range(len(plt_fitness_es_1024)):
    error1_es_1024.append(plt_fitness_es_1024[i] + plt_std_es_1024[i])
    error2_es_1024.append(plt_fitness_es_1024[i] - plt_std_es_1024[i])

plt.figure(figsize=(12, 6))
plt.xlim(left=0, right=22500)
plt.ylim(-2, 5000)

# DE 128
plt.plot(plt_eval_de_128, plt_fitness_de_128, label='DE-128')
plt.fill_between(plt_eval_de_128, error1_de_128, error2_de_128, alpha=0.2)

# DE 1024
plt.plot(plt_eval_de_1024, plt_fitness_de_1024, label='DE-1024')
plt.fill_between(plt_eval_de_1024, error1_de_1024, error2_de_1024, alpha=0.2)

# ES 128
plt.plot(plt_eval_es_128, plt_fitness_es_128,label='ES-128')
plt.fill_between(plt_eval_es_128, error1_es_128, error2_es_128, alpha=0.2)

# ES 1024
plt.plot(plt_eval_es_1024, plt_fitness_es_1024, label='ES-1024')
plt.fill_between(plt_eval_es_1024, error1_es_1024, error2_es_1024, alpha=0.2)

plt.xlabel('Number of function evaluations')
plt.ylabel('Best fitness')
plt.legend()
plt.savefig('Rosenbrock-10d.png')
plt.show()

# %% [markdown]
# ## Griewank

# %% [markdown]
# ### d = 2

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Griewank#@param
seed_number = 19520925#@param
popsize = 128#@param
bound_lower = -600
bound_upper = 600

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_128 = []
plt_std_de_128 = []
plt_eval_de_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_128.append(np.mean(fitness))
    plt_std_de_128.append(np.std(fitness))
    plt_eval_de_128.append(np.mean(eval))

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Griewank#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -600
bound_upper = 600

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_1024 = []
plt_std_de_1024 = []
plt_eval_de_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_1024.append(np.mean(fitness))
    plt_std_de_1024.append(np.std(fitness))
    plt_eval_de_1024.append(np.mean(eval))

# %%
dimension = 2#@param
test_function = Griewank#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -600#@param
bound_upper = 600#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_128 = []
plt_std_es_128 = []
plt_eval_es_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_128.append(np.mean(fitness))
    plt_std_es_128.append(np.std(fitness))
    plt_eval_es_128.append(np.mean(eval))

# %%
dimension = 2#@param
test_function = Griewank#@param
max_evals = 1e5#@param
seed_number = 19520926#@param
bound_lower = -600#@param
bound_upper = 600#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_1024 = []
plt_std_es_1024 = []
plt_eval_es_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_1024.append(np.mean(fitness))
    plt_std_es_1024.append(np.std(fitness))
    plt_eval_es_1024.append(np.mean(eval))

# %%
error1_de_128, error2_de_128 = [], []
for i in range(len(plt_fitness_de_128)):
    error1_de_128.append(plt_fitness_de_128[i] + plt_std_de_128[i])
    error2_de_128.append(plt_fitness_de_128[i] - plt_std_de_128[i])

error1_de_1024, error2_de_1024 = [], []
for i in range(len(plt_fitness_de_1024)):
    error1_de_1024.append(plt_fitness_de_1024[i] + plt_std_de_1024[i])
    error2_de_1024.append(plt_fitness_de_1024[i] - plt_std_de_1024[i])

error1_es_128, error2_es_128 = [], []
for i in range(len(plt_fitness_es_128)):
    error1_es_128.append(plt_fitness_es_128[i] + plt_std_es_128[i])
    error2_es_128.append(plt_fitness_es_128[i] - plt_std_es_128[i])

error1_es_1024, error2_es_1024 = [], []
for i in range(len(plt_fitness_es_1024)):
    error1_es_1024.append(plt_fitness_es_1024[i] + plt_std_es_1024[i])
    error2_es_1024.append(plt_fitness_es_1024[i] - plt_std_es_1024[i])

plt.figure(figsize=(12, 6))
plt.xlim(left=0, right=35000)
plt.ylim(-2, 70)

# DE 128
plt.plot(plt_eval_de_128, plt_fitness_de_128, label='DE-128')
plt.fill_between(plt_eval_de_128, error1_de_128, error2_de_128, alpha=0.2)

# DE 1024
plt.plot(plt_eval_de_1024, plt_fitness_de_1024, label='DE-1024')
plt.fill_between(plt_eval_de_1024, error1_de_1024, error2_de_1024, alpha=0.2)

# ES 128
plt.plot(plt_eval_es_128, plt_fitness_es_128,label='ES-128')
plt.fill_between(plt_eval_es_128, error1_es_128, error2_es_128, alpha=0.2)

# ES 1024
plt.plot(plt_eval_es_1024, plt_fitness_es_1024, label='ES-1024')
plt.fill_between(plt_eval_es_1024, error1_es_1024, error2_es_1024, alpha=0.2)

plt.xlabel('Number of function evaluations')
plt.ylabel('Best fitness')
plt.legend()
plt.savefig('Griewank-2d.png')
plt.show()

# %% [markdown]
# ### d = 10

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Griewank#@param
seed_number = 19520925#@param
popsize = 128#@param
bound_lower = -600
bound_upper = 600

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_128 = []
plt_std_de_128 = []
plt_eval_de_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_128.append(np.mean(fitness))
    plt_std_de_128.append(np.std(fitness))
    plt_eval_de_128.append(np.mean(eval))

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Griewank#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -600
bound_upper = 600

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_1024 = []
plt_std_de_1024 = []
plt_eval_de_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_1024.append(np.mean(fitness))
    plt_std_de_1024.append(np.std(fitness))
    plt_eval_de_1024.append(np.mean(eval))

# %%
dimension = 10#@param
test_function = Griewank#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -600#@param
bound_upper = 600#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_128 = []
plt_std_es_128 = []
plt_eval_es_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_128.append(np.mean(fitness))
    plt_std_es_128.append(np.std(fitness))
    plt_eval_es_128.append(np.mean(eval))

# %%
dimension = 10#@param
test_function = Griewank#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -600#@param
bound_upper = 600#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_1024 = []
plt_std_es_1024 = []
plt_eval_es_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_1024.append(np.mean(fitness))
    plt_std_es_1024.append(np.std(fitness))
    plt_eval_es_1024.append(np.mean(eval))

# %%
error1_de_128, error2_de_128 = [], []
for i in range(len(plt_fitness_de_128)):
    error1_de_128.append(plt_fitness_de_128[i] + plt_std_de_128[i])
    error2_de_128.append(plt_fitness_de_128[i] - plt_std_de_128[i])

error1_de_1024, error2_de_1024 = [], []
for i in range(len(plt_fitness_de_1024)):
    error1_de_1024.append(plt_fitness_de_1024[i] + plt_std_de_1024[i])
    error2_de_1024.append(plt_fitness_de_1024[i] - plt_std_de_1024[i])

error1_es_128, error2_es_128 = [], []
for i in range(len(plt_fitness_es_128)):
    error1_es_128.append(plt_fitness_es_128[i] + plt_std_es_128[i])
    error2_es_128.append(plt_fitness_es_128[i] - plt_std_es_128[i])

error1_es_1024, error2_es_1024 = [], []
for i in range(len(plt_fitness_es_1024)):
    error1_es_1024.append(plt_fitness_es_1024[i] + plt_std_es_1024[i])
    error2_es_1024.append(plt_fitness_es_1024[i] - plt_std_es_1024[i])

plt.figure(figsize=(12, 6))
plt.xlim(left=0, right=10000)
plt.ylim(-2, 500)

# DE 128
plt.plot(plt_eval_de_128, plt_fitness_de_128, label='DE-128')
plt.fill_between(plt_eval_de_128, error1_de_128, error2_de_128, alpha=0.2)

# DE 1024
plt.plot(plt_eval_de_1024, plt_fitness_de_1024, label='DE-1024')
plt.fill_between(plt_eval_de_1024, error1_de_1024, error2_de_1024, alpha=0.2)

# ES 128
plt.plot(plt_eval_es_128, plt_fitness_es_128,label='ES-128')
plt.fill_between(plt_eval_es_128, error1_es_128, error2_es_128, alpha=0.2)

# ES 1024
plt.plot(plt_eval_es_1024, plt_fitness_es_1024, label='ES-1024')
plt.fill_between(plt_eval_es_1024, error1_es_1024, error2_es_1024, alpha=0.2)

plt.xlabel('Number of function evaluations')
plt.ylabel('Best fitness')
plt.legend()
plt.savefig('Griewank-10d.png')
plt.show()

# %% [markdown]
# ## Ackley

# %% [markdown]
# ### d = 2

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Ackley#@param
seed_number = 19520925#@param
popsize = 128#@param
bound_lower = -33
bound_upper = 433

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_128 = []
plt_std_de_128 = []
plt_eval_de_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_128.append(np.mean(fitness))
    plt_std_de_128.append(np.std(fitness))
    plt_eval_de_128.append(np.mean(eval))

# %%
all_results = []

dimension = 2#@param
max_evals = 1e5#@param
test_function = Ackley#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -33
bound_upper = 433

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_1024 = []
plt_std_de_1024 = []
plt_eval_de_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_1024.append(np.mean(fitness))
    plt_std_de_1024.append(np.std(fitness))
    plt_eval_de_1024.append(np.mean(eval))

# %%
dimension = 2#@param
test_function = Ackley#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_128 = []
plt_std_es_128 = []
plt_eval_es_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_128.append(np.mean(fitness))
    plt_std_es_128.append(np.std(fitness))
    plt_eval_es_128.append(np.mean(eval))

# %%
dimension = 2#@param
test_function = Ackley#@param
max_evals = 1e5#@param
seed_number = 19520926#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_1024 = []
plt_std_es_1024 = []
plt_eval_es_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_1024.append(np.mean(fitness))
    plt_std_es_1024.append(np.std(fitness))
    plt_eval_es_1024.append(np.mean(eval))

# %%
error1_de_128, error2_de_128 = [], []
for i in range(len(plt_fitness_de_128)):
    error1_de_128.append(plt_fitness_de_128[i] + plt_std_de_128[i])
    error2_de_128.append(plt_fitness_de_128[i] - plt_std_de_128[i])

error1_de_1024, error2_de_1024 = [], []
for i in range(len(plt_fitness_de_1024)):
    error1_de_1024.append(plt_fitness_de_1024[i] + plt_std_de_1024[i])
    error2_de_1024.append(plt_fitness_de_1024[i] - plt_std_de_1024[i])

error1_es_128, error2_es_128 = [], []
for i in range(len(plt_fitness_es_128)):
    error1_es_128.append(plt_fitness_es_128[i] + plt_std_es_128[i])
    error2_es_128.append(plt_fitness_es_128[i] - plt_std_es_128[i])

error1_es_1024, error2_es_1024 = [], []
for i in range(len(plt_fitness_es_1024)):
    error1_es_1024.append(plt_fitness_es_1024[i] + plt_std_es_1024[i])
    error2_es_1024.append(plt_fitness_es_1024[i] - plt_std_es_1024[i])

plt.figure(figsize=(10, 5))
plt.xlim(left=0, right=40000)
plt.ylim(-2, 25)

# DE 128
plt.plot(plt_eval_de_128, plt_fitness_de_128, label='DE-128')
plt.fill_between(plt_eval_de_128, error1_de_128, error2_de_128, alpha=0.2)

# DE 1024
plt.plot(plt_eval_de_1024, plt_fitness_de_1024, label='DE-1024')
plt.fill_between(plt_eval_de_1024, error1_de_1024, error2_de_1024, alpha=0.2)

# ES 128
plt.plot(plt_eval_es_128, plt_fitness_es_128,label='ES-128')
plt.fill_between(plt_eval_es_128, error1_es_128, error2_es_128, alpha=0.2)

# ES 1024
plt.plot(plt_eval_es_1024, plt_fitness_es_1024, label='ES-1024')
plt.fill_between(plt_eval_es_1024, error1_es_1024, error2_es_1024, alpha=0.2)

plt.xlabel('Number of function evaluations')
plt.ylabel('Best fitness')
plt.legend()
plt.savefig('Ackley-2d.png')
plt.show()

# %% [markdown]
# ### d = 10

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Ackley#@param
seed_number = 19520925#@param
popsize = 128#@param
bound_lower = -33
bound_upper = 433

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_128 = []
plt_std_de_128 = []
plt_eval_de_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_128.append(np.mean(fitness))
    plt_std_de_128.append(np.std(fitness))
    plt_eval_de_128.append(np.mean(eval))

# %%
all_results = []

dimension = 10#@param
max_evals = 1e6#@param
test_function = Ackley#@param
seed_number = 19520925#@param
popsize = 1024#@param
bound_lower = -33
bound_upper = 433

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = DE(test_function, dimension, [(bound_lower, bound_upper)]*dimension, F_scale, cross_prob, popsize, max_evals)
    all_results.append(results)
    seed_number += 1

plt_fitness_de_1024 = []
plt_std_de_1024 = []
plt_eval_de_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_de_1024.append(np.mean(fitness))
    plt_std_de_1024.append(np.std(fitness))
    plt_eval_de_1024.append(np.mean(eval))

# %%
dimension = 10#@param
test_function = Ackley#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 128#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_128 = []
plt_std_es_128 = []
plt_eval_es_128 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_128.append(np.mean(fitness))
    plt_std_es_128.append(np.std(fitness))
    plt_eval_es_128.append(np.mean(eval))

# %%
dimension = 10#@param
test_function = Ackley#@param
max_evals = 1e6#@param
seed_number = 19520925#@param
bound_lower = -33#@param
bound_upper = 433#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.rand(seed_number)
all_results = []

for i in range(10):
    np.random.rand(seed_number)
    results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
    all_results.append(results)
    seed_number += 1

plt_fitness_es_1024 = []
plt_std_es_1024 = []
plt_eval_es_1024 = []
for i in range(np.min([len(all_results[t]) for t in range(10)])):
    fitness = []
    eval = []
    for j in range(10):
        fitness.append(all_results[j][i][1])
        eval.append(all_results[j][i][2])
    plt_fitness_es_1024.append(np.mean(fitness))
    plt_std_es_1024.append(np.std(fitness))
    plt_eval_es_1024.append(np.mean(eval))

# %%
error1_de_128, error2_de_128 = [], []
for i in range(len(plt_fitness_de_128)):
    error1_de_128.append(plt_fitness_de_128[i] + plt_std_de_128[i])
    error2_de_128.append(plt_fitness_de_128[i] - plt_std_de_128[i])

error1_de_1024, error2_de_1024 = [], []
for i in range(len(plt_fitness_de_1024)):
    error1_de_1024.append(plt_fitness_de_1024[i] + plt_std_de_1024[i])
    error2_de_1024.append(plt_fitness_de_1024[i] - plt_std_de_1024[i])

error1_es_128, error2_es_128 = [], []
for i in range(len(plt_fitness_es_128)):
    error1_es_128.append(plt_fitness_es_128[i] + plt_std_es_128[i])
    error2_es_128.append(plt_fitness_es_128[i] - plt_std_es_128[i])

error1_es_1024, error2_es_1024 = [], []
for i in range(len(plt_fitness_es_1024)):
    error1_es_1024.append(plt_fitness_es_1024[i] + plt_std_es_1024[i])
    error2_es_1024.append(plt_fitness_es_1024[i] - plt_std_es_1024[i])

plt.figure(figsize=(12, 6))
plt.xlim(left=0, right=2z0000)
plt.ylim(19, 22)

# DE 128
plt.plot(plt_eval_de_128, plt_fitness_de_128, label='DE-128')
plt.fill_between(plt_eval_de_128, error1_de_128, error2_de_128, alpha=0.2)

# DE 1024
plt.plot(plt_eval_de_1024, plt_fitness_de_1024, label='DE-1024')
plt.fill_between(plt_eval_de_1024, error1_de_1024, error2_de_1024, alpha=0.2)

# ES 128
plt.plot(plt_eval_es_128, plt_fitness_es_128,label='ES-128')
plt.fill_between(plt_eval_es_128, error1_es_128, error2_es_128, alpha=0.2)

# ES 1024
plt.plot(plt_eval_es_1024, plt_fitness_es_1024, label='ES-1024')
plt.fill_between(plt_eval_es_1024, error1_es_1024, error2_es_1024, alpha=0.2)

plt.xlabel('Number of function evaluations')
plt.ylabel('Best fitness')
plt.legend()
plt.savefig('Ackley-10d.png')
plt.show()

# %% [markdown]
# # Gif plot

# %%
test_function = Sphere#@param
dimension = 2
popsize= 32#@param

bound_lower, bound_upper = -3, 3
x = np.linspace(bound_lower, bound_upper, 100)
y = np.linspace(bound_lower, bound_upper, 100)
X, Y = np.meshgrid(x, y)
Z = test_function([X, Y])

plt.figure(figsize=(6, 6))
plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
plt.axis('square')
plt.plot()
for generation in range(generation_count - 1):
    plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
    plt.axis('square')
    plt.scatter(all_pops[generation][:, 0], all_pops[generation][:, 1], s=20, c='#ff0000', marker='o')
    display.display(plt.gcf())
    plt.clf()
    display.clear_output(wait=True)
    
plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
plt.axis('square')
plt.scatter(all_pops[generation][:, 0], all_pops[generation][:, 1], s=20, c='#ff0000', marker='o')
display.display(plt.gcf())
display.clear_output(wait=True) 
plt.show()

# %% [markdown]
# ### Griewank

# %%
dimension = 2#@param
test_function = Griewank#@param
max_evals = 1e5#@param
seed_number = 19520925#@param
bound_lower = -50#@param
bound_upper = 50#@param
popsize = 1024#@param
bounds = [(bound_lower, bound_upper)]*dimension
np.random.seed(19520925)

results, all_pops, generation_count = ES(test_function, bounds, sigma_init, c_inc, c_dec, popsize, max_evals, dimension)
x = np.linspace(bound_lower, bound_upper, 100)
y = np.linspace(bound_lower, bound_upper, 100)
X, Y = np.meshgrid(x, y)
Z = test_function([X, Y])

plt.figure(figsize=(6, 6))
plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
plt.axis('square')
plt.plot()

for generation in range(generation_count - 1):
    plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
    plt.axis('square')
    plt.scatter(all_pops[generation][:, 0], all_pops[generation][:, 1], s=20, c='#ff0000', marker='o')
    display.display(plt.gcf())
    plt.clf()
    display.clear_output(wait=True)

plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
plt.axis('square')
plt.scatter(all_pops[generation][:, 0], all_pops[generation][:, 1], s=20, c='#ff0000', marker='o')
display.display(plt.gcf())
display.clear_output(wait=True) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-134-23668773e6df> in <module>()
#      21
#      22 for generation in range(generation_count - 1):
# ---> 23     plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
#      24     plt.axis('square')
#      25     plt.scatter(all_pops[generation][:, 0], all_pops[generation][:, 1], s=20, c='#ff0000', marker='o')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2497     __ret = gca().contourf(
#    2498         *args, **({"data": data} if data is not None else {}),
# -> 2499         **kwargs)
#    2500     if __ret._A is not None: sci(__ret)  # noqa
#    2501     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
# ...

# %% [markdown]
# ### Rosenbrock

# %%
test_function = Griewank#@param
dimension=2
popsize= 3#@param
bound_lower = -600#@param
bound_upper = 600#@param


x = np.linspace(bound_lower, bound_upper, 100)
y = np.linspace(bound_lower, bound_upper, 100)
X, Y = np.meshgrid(x, y)
Z = test_function([X, Y])

plt.figure(figsize=(6, 6))
plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
plt.axis('square')
plt.plot()

for generation in range(generation_count - 1):
    plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
    plt.axis('square')
    plt.scatter(all_pops[generation][:, 0], all_pops[generation][:, 1], s=20, c='#ff0000', marker='o')
    display.display(plt.gcf())
    plt.clf()
    display.clear_output(wait=True)
generation = generation_count
plt.contourf(X, Y, Z, popsize, cmap='viridis', alpha=0.8)
plt.axis('square')
plt.scatter(all_pops[generation][:, 0], all_pops[generation][:, 1], s=20, c='#ff0000', marker='o')
display.display(plt.gcf())
display.clear_output(wait=True) 
plt.show()
